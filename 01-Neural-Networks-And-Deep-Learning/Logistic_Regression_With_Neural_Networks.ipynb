# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import numpy as np
import matplotlib.pyplot as plt
import h5py
import scipy
from PIL import Image
from scipy import ndimage
import os
#from lr_utils import load_dataset

# %matplotlib inline

# %%
path = '/content/drive/MyDrive/Colab Notebooks/deep_learning_specialization/datasets/'

print(os.path.join(path, 'train_catvnoncat.h5'))

def load_dataset():
    train_dataset = h5py.File(os.path.join(path, 'train_catvnoncat.h5'), "r")
    train_set_x_orig = np.array(train_dataset["train_set_x"][:]) # your train set features
    train_set_y_orig = np.array(train_dataset["train_set_y"][:]) # your train set labels

    test_dataset = h5py.File(os.path.join(path, 'test_catvnoncat.h5'), "r")
    test_set_x_orig = np.array(test_dataset["test_set_x"][:]) # your test set features
    test_set_y_orig = np.array(test_dataset["test_set_y"][:]) # your test set labels

    classes = np.array(test_dataset["list_classes"][:]) # the list of classes
    
    train_set_y_orig = train_set_y_orig.reshape((1, train_set_y_orig.shape[0]))
    test_set_y_orig = test_set_y_orig.reshape((1, test_set_y_orig.shape[0]))
    
    return train_set_x_orig, train_set_y_orig, test_set_x_orig, test_set_y_orig, classes
# Out:
# /content/drive/MyDrive/Colab Notebooks/deep_learning_specialization/datasets/train_catvnoncat.h5

# %%
# Loading the data (cat/non-cat)
train_set_x_orig, train_set_y, test_set_x_orig, test_set_y, classes = load_dataset()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-4-edd22496ab38> in <module>()
#       1 # Loading the data (cat/non-cat)
# ----> 2 train_set_x_orig, train_set_y, test_set_x_orig, test_set_y, classes = load_dataset()
#
# <ipython-input-3-e4f904fbf9fd> in load_dataset()
#       2
#       3 def load_dataset():
# ----> 4     train_dataset = h5py.File(os.path.join(path, 'train_catvnoncat.h5'), "r")
#       5     train_set_x_orig = np.array(train_dataset["train_set_x"][:]) # your train set features
#       6     train_set_y_orig = np.array(train_dataset["train_set_y"][:]) # your train set labels
#
# /usr/local/lib/python3.7/dist-packages/h5py/_hl/files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, **kwds)
# ...
