# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/deep_learning_specialization
# Out:
# /content/drive/MyDrive/Colab Notebooks/deep_learning_specialization

# %%
# !pwd && ls -al
# Out:
# /content/drive/MyDrive/Colab Notebooks/deep_learning_specialization
# total 26
# drwx------ 2 root root 4096 Aug  9 12:05 01-Neural-Networks-And-Deep-Learning
# drwx------ 2 root root 4096 Aug 18 11:23 02-Improving-Deep-Neural-Networks
# drwx------ 2 root root 4096 Aug 27 12:56 03-Convolutional-Neural_Networks
# drwx------ 2 root root 4096 Sep  8 13:37 04-Sequence-Models
# drwx------ 2 root root 4096 Aug  9 12:15 datasets
# drwx------ 2 root root 4096 Aug  9 12:37 .git
# -rw------- 1 root root  159 Aug  6 07:59 gitignore
# -rw------- 1 root root 1336 Sep 23 13:17 git.ipynb

# %%
#!git init
# !git config --global user.email "fromptj@gmail.com"
# !git config --global user.name "fromptj"

# %%
# !git pull origin master

# %%
# !git remote remove origin

# %%
# !git remote add origin https://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@github.com/fromptj/deep_learning_specialization.git

# %%
# !git add .
# !git commit -m "remove private files"
# !git push origin master
# Out:
# [master c774f4a] remove private files
#  1 file changed, 1 insertion(+), 1 deletion(-)
# Counting objects: 6, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (6/6), done.
# Writing objects: 100% (6/6), 1024 bytes | 341.00 KiB/s, done.
# Total 6 (delta 4), reused 0 (delta 0)
# remote: Resolving deltas: 100% (4/4), completed with 2 local objects.
# To https://github.com/fromptj/deep_learning_specialization.git
#    52dd111..c774f4a  master -> master

# %%
# !git rm -r --cached git.ipynb
# Out:
# rm 'git.ipynb'
