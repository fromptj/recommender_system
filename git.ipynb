# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# !pwd && ls -al
# Out:
# /content
# total 20
# drwxr-xr-x 1 root root 4096 Sep 13 13:34 .
# drwxr-xr-x 1 root root 4096 Sep 13 13:34 ..
# drwxr-xr-x 4 root root 4096 Sep  1 19:26 .config
# drwx------ 5 root root 4096 Sep 13 13:34 drive
# drwxr-xr-x 1 root root 4096 Sep  1 19:26 sample_data

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/drive/My Drive/Colab Notebooks/deep_learning_specialization/.git/

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/deep_learning_specialization
#!git init
# !git config --global user.email "fromptj@gmail.com"
# !git config --global user.name "fromptj"
# Out:
# /content/drive/MyDrive/Colab Notebooks/deep_learning_specialization

# %%
# !git remote remove origin

# %%
# !git remote add origin https://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/fromptj/deep_learning_specialization.git

# %%
# !git add .
# !git commit -m "transformer modeling"
# !git push origin master
# Out:
# On branch master
# nothing to commit, working tree clean
# fatal: unable to access 'https://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/fromptj/deep_learning_specialization.git/': Could not resolve host: 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
