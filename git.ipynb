# %%
from google.colab import drive
drive.mount('/content/drive/')

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/deep_learning_specialization

# %%
# !pwd && ls -al

# %%
# !git init
# !git config --global user.email "fromptj@gmail.com"
# !git config --global user.name "fromptj"

# %%
# !git remote add origin https://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@github.com/fromptj/tensorflow_certificate.git

# %%
# !git add .
# !git commit -m "sunspots prediction modeling"
# !git push origin master
