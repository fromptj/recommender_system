# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd gdrive/MyDrive/Colab Notebooks/deep_learning_specialization

# %%
# !pwd && ls -al
# Out:
# /content/gdrive/My Drive/Colab Notebooks/deep_learning_specialization
# total 15
# drwx------ 2 root root 4096 Aug  9 12:05 01-Neural-Networks-And-Deep-Learning
# drwx------ 2 root root 4096 Aug  9 12:15 datasets
# drwx------ 2 root root 4096 Aug  9 12:37 .git
# -rw------- 1 root root  159 Aug  6 07:59 gitignore
# -rw------- 1 root root 1744 Aug 14 12:28 git.ipynb

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/gdrive/My Drive/Colab Notebooks/deep_learning_specialization/.git/

# %%
# !git config --global user.email "fromptj@gmail.com"
# !git config --global user.name "fromptj"

# %%
# !git remote rm origin

# %%
# !git remote add origin https://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@github.com/fromptj/deep_learning_specialization.git
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %%
# !git add .
# !git commit -m "add regularization, gradient_checking, initialization"
# !git push origin master
# Out:
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git
