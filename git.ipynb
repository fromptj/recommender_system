# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/deep_learning_specialization
# Out:
# [Errno 2] No such file or directory: '/content/drive/MyDrive/Colab Notebooks/deep_learning_specialization'
# /content

# %%
# !pwd && ls -al
# Out:
# /content
# total 24
# drwxr-xr-x 1 root root 4096 Aug  9 12:31 .
# drwxr-xr-x 1 root root 4096 Aug  9 12:31 ..
# drwxr-xr-x 4 root root 4096 Jul 16 13:19 .config
# drwx------ 5 root root 4096 Aug  9 12:31 gdrive
# drwxr-xr-x 7 root root 4096 Aug  9 12:35 .git
# drwxr-xr-x 1 root root 4096 Jul 16 13:20 sample_data

# %%
# !git init
# !git config --global user.email "fromptj@gmail.com"
# !git config --global user.name "fromptj"
# Out:
# Reinitialized existing Git repository in /content/.git/

# %%
# !git remote add origin https://fromptj:tlgja147@github.com/fromptj/deep_learning_specialization.git
# Out:
# fatal: remote origin already exists.

# %%
# !git add .
# !git commit -m "첫번째 커밋"
# !git push origin master
