# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/deep_learning_specialization
# Out:
# /content/drive/MyDrive/Colab Notebooks/deep_learning_specialization

# %%
# !pwd && ls -al
# Out:
# /content/drive/MyDrive/Colab Notebooks/deep_learning_specialization
# total 12
# drwx------ 2 root root 4096 Aug  9 12:05 01-Neural-Networks-And-Deep-Learning
# drwx------ 2 root root 4096 Aug  9 12:15 datasets
# -rw------- 1 root root  159 Aug  6 07:59 gitignore
# -rw------- 1 root root 3461 Aug  9 12:36 git.ipynb

# %%
# !git init
# !git config --global user.email "fromptj@gmail.com"
# !git config --global user.name "fromptj"
# Out:
# Initialized empty Git repository in /content/drive/MyDrive/Colab Notebooks/deep_learning_specialization/.git/

# %%
# !git remote add origin https://fromptj:tlgja147@github.com/fromptj/deep_learning_specialization.git

# %%
# !git add .
# !git commit -m "첫번째 커밋"
# !git push origin master
# Out:
# [master (root-commit) f6a1ef2] 첫번째 커밋
#  5 files changed, 6 insertions(+)
#  create mode 100644 01-Neural-Networks-And-Deep-Learning/Logistic_Regression_With_Neural_Networks.ipynb
#  create mode 100644 datasets/test_catvnoncat.h5
#  create mode 100644 datasets/train_catvnoncat.h5
#  create mode 100644 git.ipynb
#  create mode 100644 gitignore
# Counting objects: 9, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (9/9), done.
# Writing objects: 100% (9/9), 2.66 MiB | 5.47 MiB/s, done.
# Total 9 (delta 1), reused 0 (delta 0)
# remote: Resolving deltas: 100% (1/1), done.
# To https://github.com/fromptj/deep_learning_specialization.git
#  * [new branch]      master -> master
