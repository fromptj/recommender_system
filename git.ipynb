# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# !pwd && ls -al
# Out:
# /content
# total 20
# drwxr-xr-x 1 root root 4096 Sep 13 13:34 .
# drwxr-xr-x 1 root root 4096 Sep 13 13:34 ..
# drwxr-xr-x 4 root root 4096 Sep  1 19:26 .config
# drwx------ 5 root root 4096 Sep 13 13:34 drive
# drwxr-xr-x 1 root root 4096 Sep  1 19:26 sample_data

# %%
# !git init
# Out:
# Initialized empty Git repository in /content/.git/

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/deep_learning_specialization
#!git init
# !git config --global user.email "fromptj@gmail.com"
# !git config --global user.name "fromptj"
# Out:
# /content/drive/MyDrive/Colab Notebooks/deep_learning_specialization

# %%
# !git remote add origin https://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@github.com/fromptj/deep_learning_specialization.git
# Out:
# fatal: remote origin already exists.

# %%
# !git add .
# !git commit -m "music generation lstm"
# !git push origin master
# Out:
# [master 615a0aa] music generation lstm
#  2 files changed, 2 insertions(+)
#  create mode 100644 04-Sequence-Models/Jazz_Improvisation_With_LSTM.ipynb
#  create mode 100644 git.ipynb
# Counting objects: 5, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (5/5), done.
# Writing objects: 100% (5/5), 3.43 KiB | 1.14 MiB/s, done.
# Total 5 (delta 2), reused 0 (delta 0)
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/fromptj/deep_learning_specialization.git
#    0f9842d..615a0aa  master -> master
