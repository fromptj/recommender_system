# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# !pwd && ls -al
# Out:
# /content/drive/My Drive/Colab Notebooks/deep_learning_specialization
# total 31
# drwx------ 2 root root 4096 Aug  9 12:05 01-Neural-Networks-And-Deep-Learning
# drwx------ 2 root root 4096 Aug 18 11:23 02-Improving-Deep-Neural-Networks
# drwx------ 2 root root 4096 Aug 27 12:56 03-Convolutional-Neural_Networks
# drwx------ 2 root root 4096 Sep  8 13:37 04-Sequence-Models
# drwx------ 2 root root 4096 Aug  9 12:15 datasets
# drwx------ 8 root root 4096 Sep 22 10:59 .git
# -rw------- 1 root root  159 Aug  6 07:59 gitignore
# -rw------- 1 root root 5968 Sep 22 11:00 git.ipynb

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/drive/My Drive/Colab Notebooks/deep_learning_specialization/.git/

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/deep_learning_specialization
#!git init
# !git config --global user.email "fromptj@gmail.com"
# !git config --global user.name "fromptj"
# Out:
# /content/drive/MyDrive/Colab Notebooks/deep_learning_specialization

# %%
# !git remote remove origin

# %%
# !git remote add origin https://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/fromptj/deep_learning_specialization.git
# Out:
# fatal: remote origin already exists.

# %%
# !git config --global http.proxy http://proxyuser:proxypwd@proxy.server.com:8080

# %%
# !git config --global --unset http.proxy 
# !git config --global --unset https.proxy

# %%
# !ping github.com
# Out:
# /bin/bash: ping: command not found

# %%
# !git add .
# !git commit -m "transformer modeling"
# !git push origin master
# Out:
# [master 3e4c862] transformer modeling
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite git.ipynb (83%)
# fatal: unable to access 'https://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/fromptj/deep_learning_specialization.git/': Could not resolve host: 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
